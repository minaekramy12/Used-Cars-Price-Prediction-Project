# %% [markdown]
# ## Installing Dependencies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.svm import SVR

from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error, r2_score
from sklearn.inspection import permutation_importance


import joblib

# %% [markdown]
# ## Loading Data

# %%
data = pd.read_csv('../data/clean_data.csv')
data.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  Infiniti                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#   transmission                 ext_col int_col  \
# 0    Automatic                   Black   Black
# 1    Automatic         Moonlight Cloud    Gray
# ...

# %%
data.isnull().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type       215
# engine            0
# transmission     85
# ext_col           0
# int_col           0
# accident        113
# clean_title     596
# price             0
# HP              810
# engine_size     238
# n_cylinders     622
# dtype: int64

# %% [markdown]
# ## Feature creation

# %%
data['age'] = datetime.now().year - data.model_year

# %%
data = data.drop(columns=['model_year', 'ext_col', 'int_col', 'model', 'engine', 'clean_title'])

# %% [markdown]
# We had to drop `model`, as by encoding this column it might lead to overfitting.
#
# We also dropped `clean title` as it only contains ('Yes', NaN), so we can't say that `NaN` is 'No'.

# %%
data.head()
# Out:
#       brand   milage      fuel_type transmission  \
# 0      Ford  51000.0  E85 Flex Fuel    Automatic
# 1   Hyundai  34742.0       Gasoline    Automatic
# 2     Lexus  22372.0       Gasoline    Automatic
# 3  Infiniti  88900.0         Hybrid    Automatic
# 4      Audi   9835.0       Gasoline    Automatic
#
#                                  accident    price     HP  engine_size  \
# 0  At least 1 accident or damage reported  10300.0  300.0          3.7
# 1  At least 1 accident or damage reported  38005.0    NaN          3.8
# 2                           None reported  54598.0    NaN          3.5
# 3                           None reported  15500.0  354.0          3.5
# 4                           None reported  34999.0    NaN          2.0
#
#    n_cylinders  age
# 0          6.0   13
# 1          6.0    5
# 2          NaN    4
# 3          6.0   11
# 4          NaN    5

# %%
numerical_features = ['milage', 'HP', 'engine_size', 'n_cylinders', 'age']
categorical_features = ['brand', 'fuel_type', 'transmission', 'accident']

# %% [markdown]
# ## Pipelines

# %%
numerical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('endcoder', OneHotEncoder(handle_unknown='ignore'))
])

# ====================================================
# numerical_pipeline2 = Pipeline([
#     ('imputer', KNNImputer(weights='distance')),
#     ('scaler', RobustScaler())
# ])

# categorical_pipeline2 = Pipeline([
#     ('imputer', SimpleImputer(strategy='constant', fill_value='unknown')),
#     ('endcoder', OneHotEncoder(handle_unknown='ignore'))
# ])
numerical_pipeline2 = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', RobustScaler())
])

categorical_pipeline2 = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value='unknown')),
    ('endcoder', OneHotEncoder(handle_unknown='ignore'))
])



# ====================================================

preprocessor = ColumnTransformer([
    ('num', numerical_pipeline, numerical_features),
    ('cat', categorical_pipeline, categorical_features)
])

preprocessor2 = ColumnTransformer([
    ('num', numerical_pipeline2, numerical_features),
    ('cat', categorical_pipeline2, categorical_features)
])

# ====================================================

lr_model_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LinearRegression())
])

poly_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('poly', PolynomialFeatures()),
    ('model', LinearRegression())
])

dt_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', DecisionTreeRegressor(random_state=42))
])


rf_pipeline = Pipeline([
    ('preprocessor', preprocessor2),
    ('model', RandomForestRegressor(random_state=42))
])

xgb_pipeline = Pipeline([
    ('preprocessor', preprocessor2),
    ('model', XGBRegressor(n_estimators=300, random_state=42, eval_metric='mae'))
])


svr_pipeline = Pipeline([
    ('preprocessor', preprocessor2),
    ('model', SVR())
])

# %% [markdown]
# ## Define Metrics Function

# %%
def print_metrics (model, y_test, y_predict):
    mae = mean_absolute_error(np.expm1(y_test), np.expm1(y_predict))
    mse = mean_squared_error(np.expm1(y_test), np.expm1(y_predict))
    rmse = root_mean_squared_error(np.expm1(y_test), np.expm1(y_predict))
    r2 = r2_score(y_test, y_predict)

    print(f'===== {model} =====')
    print(f'MAE: {mae:.2f}')
    print(f'MSE: {mse:.2f}')
    print(f'RMSE: {rmse:.2f}')
    print(f'R2: {100 * r2:.3f}%')

# %% [markdown]
# ## Transforming Target Variable

# %%
X = data.drop(columns=['price'])
y = data.price

# %%
y = np.log1p(y)

# %%
plt.hist(y, bins=50)
plt.show()

# %%
y.skew()
# Out:
# np.float64(0.10572635355073637)

# %% [markdown]
# ## Splitting The Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# ## Linear Regression Model

# %% [markdown]
# ### Training The Model

# %%
lr_model_pipeline.fit(X_train, y_train)
y_prediction = lr_model_pipeline.predict(X_test)

# %% [markdown]
# ### Print Metrics

# %%
print_metrics('Linear Regression', y_test, y_prediction)
# Out:
# ===== Linear Regression =====
# MAE: 19392.08
# MSE: 18874565420.21
# RMSE: 137384.74
# R2: 76.735%

# %% [markdown]
# ### Cross Validation

# %%
lr_scores = cross_val_score(
    lr_model_pipeline,
    X_train,
    y_train,
    cv=5,
    scoring='r2'
)

print(lr_scores)
print(lr_scores.mean())
# Out:
# [0.80610073 0.8268543  0.80794128 0.83779484 0.82121433]
# 0.8199810948047256

# %% [markdown]
# ## Polynomial Model

# %% [markdown]
# ### Training The Model

# %%
poly_pipeline.fit(X_train, y_train)

poly_prediction = poly_pipeline.predict(X_test)

# %% [markdown]
# ### Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'poly__degree': [2, 3],
    'poly__include_bias': [False, True]
}

poly_grid = GridSearchCV(
    poly_pipeline,
    param_grid,
    cv=5,
    scoring='r2',
    n_jobs=-1
)

poly_grid.fit(X_train, y_train)

print(poly_grid.best_params_)
print(poly_grid.best_score_)
# Out:
# {'poly__degree': 2, 'poly__include_bias': False}
# 0.834285700156992

# %%
best_poly = poly_grid.best_estimator_

prediction = best_poly.predict(X_test)

# %% [markdown]
# ### Print Metrics

# %%
print_metrics(
    'Polynomial Regression',
    y_test,
    prediction
)
# Out:
# ===== Polynomial Regression =====
# MAE: 17688.94
# MSE: 18071854338.24
# RMSE: 134431.60
# R2: 79.409%

# %% [markdown]
# ### Cross Validation

# %%
scores = cross_val_score(
    best_poly,
    X_train,
    y_train,
    cv=5,
    scoring='r2'
)

print(scores)
print(scores.mean())
# Out:
# [0.85611932 0.77766393 0.84037932 0.85011843 0.8471475 ]
# 0.834285700156992

# %% [markdown]
# ## Decision Tree Model

# %% [markdown]
# ### Training The Model

# %%
dt_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['milage', 'HP',
#                                                    'engine_size', 'n_cylinders',
#                                                    'age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('endcoder',
# ...

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'model__max_depth': [5, 10, 15, 20, None],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(
    estimator=dt_pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='r2',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best CV Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'model__max_depth': 10, 'model__min_samples_leaf': 2, 'model__min_samples_split': 10}
# Best CV Score: 0.7613024962699659

# %% [markdown]
# ### Print Metrics

# %%
best_tree = grid_search.best_estimator_
y_prediction = best_tree.predict(X_test)

print_metrics('Decision Tree Model', y_test, y_prediction)
# Out:
# ===== Decision Tree Model =====
# MAE: 19970.55
# MSE: 18096385503.62
# RMSE: 134522.81
# R2: 74.299%

# %% [markdown]
# ### Cross Validation

# %%
scores = cross_val_score(
    best_tree,
    X_train,
    y_train,
    cv=5,
    scoring='r2',
    n_jobs=-1
)

print("Scores:", scores)
print("Mean:", scores.mean())
print("Std:", scores.std())
# Out:
# Scores: [0.75394304 0.76807632 0.76299741 0.7571578  0.76433792]
# Mean: 0.7613024962699659
# Std: 0.0050854936757924185

# %% [markdown]
# ## Random Forest Model

# %% [markdown]
# ### Training The Model

# %%
rf_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['milage', 'HP',
#                                                    'engine_size', 'n_cylinders',
#                                                    'age', 'is_luxury']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %% [markdown]
# ### Hyperparameter Tuning

# %%
param_grid = {
    'model__n_estimators': [100, 200],
    'model__max_depth': [10, 20, None],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(
    estimator=rf_pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='r2',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best CV Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'model__max_depth': 20, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 200}
# Best CV Score: 0.8824152768075162

# %% [markdown]
# ### Print Metrics

# %%
best_rf = grid_search.best_estimator_
y_prediction = best_rf.predict(X_test)

print_metrics('Random Forest Model', y_test, y_prediction)
# Out:
# ===== Random Forest Model =====
# MAE: 15388.69
# MSE: 16924438729.45
# RMSE: 130093.96
# R2: 86.700%

# %% [markdown]
# ### Cross Validation

# %%
scores = cross_val_score(
    best_rf,
    X_train,
    y_train,
    cv=5,
    scoring='r2',
    n_jobs=-1
)

print("Scores:", scores)
print("Mean:", scores.mean())
print("Std:", scores.std())
# Out:
# Scores: [0.84884626 0.86071587 0.86217544 0.86648817 0.86234694]
# Mean: 0.8601145362676075
# Std: 0.00595298050538292

# %%
rf_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['milage', 'HP',
#                                                    'engine_size', 'n_cylinders',
#                                                    'age', 'is_luxury']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='unknown',
# ...

# %%
param_grid = {
    'model__n_estimators': [100, 200],
    'model__max_depth': [10, 20, None],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(
    estimator=rf_pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='r2',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best CV Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'model__max_depth': 20, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 200}
# Best CV Score: 0.8825266301927973

# %%
best_rf = grid_search.best_estimator_
y_prediction = best_rf.predict(X_test)

print_metrics('Random Forest Model', y_test, y_prediction)
# Out:
# ===== Random Forest Model =====
# MAE: 15412.28
# MSE: 16825625225.79
# RMSE: 129713.63
# R2: 86.839%

# %% [markdown]
# ## XGBoost

# %%
xgb_pipeline.fit(X_train, y_train)# constant 'uknown'
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['milage', 'HP',
#                                                    'engine_size', 'n_cylinders',
#                                                    'age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='unknown',
# ...

# %%
y_pred_xgb = xgb_pipeline.predict(X_test)

print_metrics('XBGoost Model', y_test, y_pred_xgb)
# Out:
# ===== XBGoost Model =====
# MAE: 15971.81
# MSE: 17511883528.39
# RMSE: 132332.47
# R2: 84.899%

# %%
xgb_pipeline.fit(X_train, y_train) # constant + robust
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['milage', 'HP',
#                                                    'engine_size', 'n_cylinders',
#                                                    'age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='unknown',
# ...

# %%
y_pred_xgb = xgb_pipeline.predict(X_test)

print_metrics('XBGoost Model', y_test, y_pred_xgb)
# Out:
# ===== XBGoost Model =====
# MAE: 15971.81
# MSE: 17511883528.39
# RMSE: 132332.47
# R2: 84.899%

# %%
xgb_pipeline.fit(X_train, y_train) # constant + robust
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['milage', 'HP',
#                                                    'engine_size', 'n_cylinders',
#                                                    'age', 'is_luxury']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='unknown',
# ...

# %%
y_pred_xgb = xgb_pipeline.predict(X_test)

print_metrics('XBGoost Model', y_test, y_pred_xgb)
# Out:
# ===== XBGoost Model =====
# MAE: 15146.58
# MSE: 16049889739.92
# RMSE: 126688.16
# R2: 87.667%

# %%
['Porsche', 'Lamborghini']

# %%
data['is_luxury'] = data.brand.map(lambda x: 1 if x == 'Porsche'  else 0).astype(int).values

# %%
xgb_pipeline.fit(X_train, y_train) # constant + robust
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['milage', 'HP',
#                                                    'engine_size', 'n_cylinders',
#                                                    'age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='unknown',
# ...

# %%
y_pred_xgb = xgb_pipeline.predict(X_test)

print_metrics('XBGoost Model', y_test, y_pred_xgb)
# Out:
# ===== XBGoost Model =====
# MAE: 15971.81
# MSE: 17511883528.39
# RMSE: 132332.47
# R2: 84.899%

# %%
preprocessor = xgb_pipeline.named_steps['preprocessor']
model = xgb_pipeline.named_steps['model']

# 2. استخراج أسماء الأعمدة بعد التجهيز (Transformation)
feature_names = preprocessor2.get_feature_names_out()

# 3. الحصول على الـ Feature Importances من الموديل
importances = model.feature_importances_

# 4. تجميعهم في DataFrame واحد وترتيبهم
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# عرض الأعمدة الأكثر أهمية
print(importance_df.head(10))
# Out:
#                    Feature  Importance
# 47      cat__brand_Porsche    0.127613
# 29  cat__brand_Lamborghini    0.104751
# 61   cat__fuel_type_Diesel    0.053342
# 16      cat__brand_Ferrari    0.048971
# 0              num__milage    0.042179
# 9       cat__brand_Bentley    0.041634
# 4                 num__age    0.036854
# 23      cat__brand_Hyundai    0.035296
# 1                  num__HP    0.029869
# 14     cat__brand_Chrysler    0.027264

# %%
# رسم أعلى 15 Feature تأثيراً
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'][:15][::-1], importance_df['Importance'][:15][::-1])
plt.xlabel('XGBoost Feature Importance')
plt.ylabel('Features')
plt.title('Top 15 Most Important Features')
plt.tight_layout()
plt.show()

# %%
sns.heatmap(
    data.select_dtypes('number').corr(),
    annot=True
)
# Out:
# <Axes: >

# %%
svr_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['milage', 'HP',
#                                                    'engine_size', 'n_cylinders',
#                                                    'age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='unknown',
# ...

# %%
y_pred_svr = svr_pipeline.predict(X_test)

print_metrics('SVR Model', y_test, y_pred_svr)
# Out:
# ===== SVR Model =====
# MAE: 16302.38
# MSE: 18601467848.17
# RMSE: 136387.20
# R2: 81.710%

# %% [markdown]
# ## Save Best Model

# %%
joblib.dump(best_rf, '../models/xgb_pipeline.joblib')
# Out:
# ['../models/xgb_pipeline.joblib']
